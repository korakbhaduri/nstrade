# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 5. Compare Results

# %% [markdown]
# ## 1. Imports and Setup

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append("../src")

from strategy import Strategy
from backtest import run_backtest
from backtester_vector import sma_crossover_vector

# %% [markdown]
# # 2. Load and clean data

# %%
# Load your BTC/USD hourly data
data_path = '../data/btc_hour.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#                         time   high    low   open  volumefrom  volumeto  \
# 0  2011-11-28 00:00:00+00:00  2.499  2.461  2.480     3457.45   8571.74
# 1  2011-11-28 01:00:00+00:00  2.498  2.480  2.497      681.46   1698.15
# 2  2011-11-28 02:00:00+00:00  2.499  2.485  2.498      624.29   1559.13
# 3  2011-11-28 03:00:00+00:00  2.498  2.442  2.487     2648.16   6519.05
# 4  2011-11-28 04:00:00+00:00  2.500  2.440  2.442     4299.98  10667.19
#
#    close conversionType conversionSymbol
# 0  2.497         direct              NaN
# 1  2.498         direct              NaN
# 2  2.487         direct              NaN
# 3  2.442         direct              NaN
# 4  2.462         direct              NaN

# %%
df
# Out:
#                              time        high         low        open  \
# 0       2011-11-28 00:00:00+00:00       2.499       2.461       2.480
# 1       2011-11-28 01:00:00+00:00       2.498       2.480       2.497
# 2       2011-11-28 02:00:00+00:00       2.499       2.485       2.498
# 3       2011-11-28 03:00:00+00:00       2.498       2.442       2.487
# 4       2011-11-28 04:00:00+00:00       2.500       2.440       2.442
# ...                           ...         ...         ...         ...
# 118054  2025-05-16 22:00:00+00:00  103649.830  103450.360  103643.590
# 118055  2025-05-16 23:00:00+00:00  103718.440  103465.470  103551.320
# 118056  2025-05-17 00:00:00+00:00  103569.600  103141.310  103499.600
# 118057  2025-05-17 01:00:00+00:00  103388.090  102642.390  103388.020
# 118058  2025-05-17 02:00:00+00:00  103316.880  102779.280  102859.210
#
#         volumefrom      volumeto       close conversionType conversionSymbol
# 0          3457.45  8.571740e+03       2.497         direct              NaN
# 1           681.46  1.698150e+03       2.498         direct              NaN
# 2           624.29  1.559130e+03       2.487         direct              NaN
# 3          2648.16  6.519050e+03       2.442         direct              NaN
# 4          4299.98  1.066719e+04       2.462         direct              NaN
# ...            ...           ...         ...            ...              ...
# 118054      978.41  1.012609e+08  103551.320         direct              NaN
# 118055      312.40  3.235507e+07  103499.600         direct              NaN
# 118056      488.11  5.044067e+07  103388.020         direct              NaN
# 118057      669.72  6.891526e+07  102859.210         direct              NaN
# 118058      263.48  2.715254e+07  103307.020         direct              NaN
#
# [118059 rows x 9 columns]

# %%
# Data cleaning: keep only time, close, volumeto; cast time to datetime; rename volumeto to volume
df = df[['time', 'close', 'volumeto']].copy()
df['time'] = pd.to_datetime(df['time'])
df = df.rename(columns={'volumeto': 'volume'})
df.head()
# Out:
#                        time  close    volume
# 0 2011-11-28 00:00:00+00:00  2.497   8571.74
# 1 2011-11-28 01:00:00+00:00  2.498   1698.15
# 2 2011-11-28 02:00:00+00:00  2.487   1559.13
# 3 2011-11-28 03:00:00+00:00  2.442   6519.05
# 4 2011-11-28 04:00:00+00:00  2.462  10667.19

# %%
df.tail()
# Out:
#                             time      close        volume
# 118054 2025-05-16 22:00:00+00:00  103551.32  1.012609e+08
# 118055 2025-05-16 23:00:00+00:00  103499.60  3.235507e+07
# 118056 2025-05-17 00:00:00+00:00  103388.02  5.044067e+07
# 118057 2025-05-17 01:00:00+00:00  102859.21  6.891526e+07
# 118058 2025-05-17 02:00:00+00:00  103307.02  2.715254e+07

# %% [markdown]
# # 3. Define strategy

# %% [markdown]
# ### Buy and Hold strategy

# %%
class BuyAndHoldStrategy(Strategy):
    def __init__(self, initial_capital=10000):
        super().__init__(initial_capital)
        self.has_bought = False

    def process_bar(self, bar):
        self.current_bar = bar

    def get_signal(self):
        if not self.has_bought:
            self.has_bought = True
            return 'buy'
        return 'hold'

# %% [markdown]
# ### SMA Crossover Strategy

# %%
class SMACrossoverStrategy(Strategy):
    def __init__(self, initial_capital=10000, fast=20, slow=100):
        super().__init__(initial_capital)
        self.prices = []
        self.fast = fast
        self.slow = slow
        self.last_signal = 'hold'

    def process_bar(self, bar):
        self.current_bar = bar
        self.prices.append(bar['close'])
        if len(self.prices) < self.slow:
            self.last_signal = 'hold'
            return

        fast_ma = pd.Series(self.prices).rolling(self.fast).mean().iloc[-1]
        slow_ma = pd.Series(self.prices).rolling(self.slow).mean().iloc[-1]

        if fast_ma > slow_ma and self.position == 0:
            self.last_signal = 'buy'
        elif fast_ma < slow_ma and self.position == 1:
            self.last_signal = 'sell'
        else:
            self.last_signal = 'hold'

    def get_signal(self):
        return self.last_signal

# %% [markdown]
# # 4. Run Backtests

# %%
bt_df = df.tail(20000).copy()
# Duplicate so both names exist
bt_df["volumeto"] = bt_df["volume"]

# quick timing check
# %timeit sma_crossover_vector(bt_df, fast=20, slow=100, fee=FEE)

sma_vec_results = sma_crossover_vector(bt_df, fast=20, slow=100, fee=FEE)


# --- backtest on development set with a 0.1 % fee per side -------------
FEE = 0.001         # change this value whenever you want to test another fee

bh_results = run_backtest(
    BuyAndHoldStrategy,
    bt_df,                 # your DataFrame or CSV path
    initial_capital=10_000,
    fee=FEE
)

sma_results = run_backtest(
    lambda initial_capital: SMACrossoverStrategy(initial_capital, fast=20, slow=100),
    bt_df,
    initial_capital=10_000,
    fee=FEE
)
# Out:
# 2.26 ms ± 81.6 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# REALIZED DD: entry_idx=0, exit_idx=19999, equity_len=20002
# REALIZED DD: entry_idx=106, exit_idx=124, equity_len=20002
# REALIZED DD: entry_idx=259, exit_idx=436, equity_len=20002
# REALIZED DD: entry_idx=568, exit_idx=643, equity_len=20002
# REALIZED DD: entry_idx=750, exit_idx=767, equity_len=20002
# REALIZED DD: entry_idx=890, exit_idx=1137, equity_len=20002
# REALIZED DD: entry_idx=1157, exit_idx=1178, equity_len=20002
# REALIZED DD: entry_idx=1226, exit_idx=1244, equity_len=20002
# REALIZED DD: entry_idx=1287, exit_idx=1391, equity_len=20002
# REALIZED DD: entry_idx=1447, exit_idx=1475, equity_len=20002
# REALIZED DD: entry_idx=1563, exit_idx=1718, equity_len=20002
# REALIZED DD: entry_idx=1781, exit_idx=1792, equity_len=20002
# REALIZED DD: entry_idx=1947, exit_idx=2056, equity_len=20002
# REALIZED DD: entry_idx=2060, exit_idx=2073, equity_len=20002
# REALIZED DD: entry_idx=2144, exit_idx=2216, equity_len=20002
# REALIZED DD: entry_idx=2405, exit_idx=2459, equity_len=20002
# REALIZED DD: entry_idx=2482, exit_idx=2499, equity_len=20002
# REALIZED DD: entry_idx=2551, exit_idx=2569, equity_len=20002
# REALIZED DD: entry_idx=2600, exit_idx=2633, equity_len=20002
# REALIZED DD: entry_idx=2698, exit_idx=2801, equity_len=20002
# REALIZED DD: entry_idx=2874, exit_idx=2917, equity_len=20002
# REALIZED DD: entry_idx=2964, exit_idx=2980, equity_len=20002
# REALIZED DD: entry_idx=3002, exit_idx=3034, equity_len=20002
# REALIZED DD: entry_idx=3112, exit_idx=3146, equity_len=20002
# REALIZED DD: entry_idx=3192, exit_idx=3421, equity_len=20002
# REALIZED DD: entry_idx=3457, exit_idx=3473, equity_len=20002
# REALIZED DD: entry_idx=3504, exit_idx=3538, equity_len=20002
# REALIZED DD: entry_idx=3547, exit_idx=3641, equity_len=20002
# REALIZED DD: entry_idx=3769, exit_idx=3830, equity_len=20002
# REALIZED DD: entry_idx=3836, exit_idx=3873, equity_len=20002
# REALIZED DD: entry_idx=4079, exit_idx=4094, equity_len=20002
# REALIZED DD: entry_idx=4168, exit_idx=4186, equity_len=20002
# REALIZED DD: entry_idx=4199, exit_idx=4248, equity_len=20002
# REALIZED DD: entry_idx=4255, exit_idx=4277, equity_len=20002
# REALIZED DD: entry_idx=4307, exit_idx=4328, equity_len=20002
# REALIZED DD: entry_idx=4449, exit_idx=4524, equity_len=20002
# REALIZED DD: entry_idx=4609, exit_idx=4624, equity_len=20002
# REALIZED DD: entry_idx=4823, exit_idx=4859, equity_len=20002
# REALIZED DD: entry_idx=4951, exit_idx=4962, equity_len=20002
# REALIZED DD: entry_idx=4963, exit_idx=5022, equity_len=20002
# REALIZED DD: entry_idx=5111, exit_idx=5115, equity_len=20002
# REALIZED DD: entry_idx=5186, exit_idx=5246, equity_len=20002
# REALIZED DD: entry_idx=5302, exit_idx=5515, equity_len=20002
# REALIZED DD: entry_idx=5669, exit_idx=5817, equity_len=20002
# REALIZED DD: entry_idx=5836, exit_idx=5858, equity_len=20002
# REALIZED DD: entry_idx=5878, exit_idx=5946, equity_len=20002
# REALIZED DD: entry_idx=6079, exit_idx=6384, equity_len=20002
# REALIZED DD: entry_idx=6430, exit_idx=6543, equity_len=20002
# REALIZED DD: entry_idx=6573, exit_idx=6644, equity_len=20002
# REALIZED DD: entry_idx=6649, exit_idx=6789, equity_len=20002
# REALIZED DD: entry_idx=6846, exit_idx=6873, equity_len=20002
# REALIZED DD: entry_idx=6905, exit_idx=6906, equity_len=20002
# REALIZED DD: entry_idx=6907, exit_idx=6927, equity_len=20002
# REALIZED DD: entry_idx=6939, exit_idx=6991, equity_len=20002
# REALIZED DD: entry_idx=7016, exit_idx=7108, equity_len=20002
# REALIZED DD: entry_idx=7156, exit_idx=7447, equity_len=20002
# REALIZED DD: entry_idx=7522, exit_idx=7572, equity_len=20002
# REALIZED DD: entry_idx=7578, exit_idx=7591, equity_len=20002
# REALIZED DD: entry_idx=7643, exit_idx=7771, equity_len=20002
# REALIZED DD: entry_idx=7856, exit_idx=7872, equity_len=20002
# REALIZED DD: entry_idx=7950, exit_idx=8021, equity_len=20002
# REALIZED DD: entry_idx=8092, exit_idx=8224, equity_len=20002
# REALIZED DD: entry_idx=8327, exit_idx=8350, equity_len=20002
# REALIZED DD: entry_idx=8557, exit_idx=8697, equity_len=20002
# REALIZED DD: entry_idx=8724, exit_idx=8788, equity_len=20002
# REALIZED DD: entry_idx=8833, exit_idx=9100, equity_len=20002
# REALIZED DD: entry_idx=9127, exit_idx=9158, equity_len=20002
# REALIZED DD: entry_idx=9161, exit_idx=9167, equity_len=20002
# REALIZED DD: entry_idx=9168, exit_idx=9183, equity_len=20002
# REALIZED DD: entry_idx=9272, exit_idx=9726, equity_len=20002
# REALIZED DD: entry_idx=9875, exit_idx=9907, equity_len=20002
# REALIZED DD: entry_idx=9964, exit_idx=10079, equity_len=20002
# REALIZED DD: entry_idx=10103, exit_idx=10106, equity_len=20002
# REALIZED DD: entry_idx=10115, exit_idx=10147, equity_len=20002
# REALIZED DD: entry_idx=10230, exit_idx=10351, equity_len=20002
# REALIZED DD: entry_idx=10382, exit_idx=10415, equity_len=20002
# REALIZED DD: entry_idx=10573, exit_idx=10706, equity_len=20002
# REALIZED DD: entry_idx=10918, exit_idx=11017, equity_len=20002
# REALIZED DD: entry_idx=11080, exit_idx=11086, equity_len=20002
# REALIZED DD: entry_idx=11150, exit_idx=11399, equity_len=20002
# REALIZED DD: entry_idx=11448, exit_idx=11513, equity_len=20002
# REALIZED DD: entry_idx=11575, exit_idx=11588, equity_len=20002
# REALIZED DD: entry_idx=11648, exit_idx=11765, equity_len=20002
# REALIZED DD: entry_idx=12246, exit_idx=12265, equity_len=20002
# REALIZED DD: entry_idx=12308, exit_idx=12370, equity_len=20002
# REALIZED DD: entry_idx=12469, exit_idx=12484, equity_len=20002
# REALIZED DD: entry_idx=12511, exit_idx=12589, equity_len=20002
# REALIZED DD: entry_idx=12609, exit_idx=12752, equity_len=20002
# REALIZED DD: entry_idx=12766, exit_idx=12861, equity_len=20002
# REALIZED DD: entry_idx=12928, exit_idx=13016, equity_len=20002
# REALIZED DD: entry_idx=13238, exit_idx=13327, equity_len=20002
# REALIZED DD: entry_idx=13375, exit_idx=13398, equity_len=20002
# REALIZED DD: entry_idx=13457, exit_idx=13503, equity_len=20002
# REALIZED DD: entry_idx=13521, exit_idx=13548, equity_len=20002
# REALIZED DD: entry_idx=13559, exit_idx=13688, equity_len=20002
# REALIZED DD: entry_idx=13856, exit_idx=13874, equity_len=20002
# REALIZED DD: entry_idx=14010, exit_idx=14175, equity_len=20002
# REALIZED DD: entry_idx=14211, exit_idx=14409, equity_len=20002
# REALIZED DD: entry_idx=14416, exit_idx=14507, equity_len=20002
# REALIZED DD: entry_idx=14620, exit_idx=14711, equity_len=20002
# REALIZED DD: entry_idx=14787, exit_idx=15025, equity_len=20002
# REALIZED DD: entry_idx=15098, exit_idx=15130, equity_len=20002
# REALIZED DD: entry_idx=15166, exit_idx=15271, equity_len=20002
# REALIZED DD: entry_idx=15384, exit_idx=15620, equity_len=20002
# REALIZED DD: entry_idx=15624, exit_idx=15838, equity_len=20002
# REALIZED DD: entry_idx=15921, exit_idx=16027, equity_len=20002
# REALIZED DD: entry_idx=16081, exit_idx=16178, equity_len=20002
# REALIZED DD: entry_idx=16249, exit_idx=16416, equity_len=20002
# REALIZED DD: entry_idx=16564, exit_idx=16611, equity_len=20002
# REALIZED DD: entry_idx=16734, exit_idx=16742, equity_len=20002
# REALIZED DD: entry_idx=16756, exit_idx=16902, equity_len=20002
# REALIZED DD: entry_idx=16999, exit_idx=17032, equity_len=20002
# REALIZED DD: entry_idx=17055, exit_idx=17219, equity_len=20002
# REALIZED DD: entry_idx=17236, exit_idx=17262, equity_len=20002
# REALIZED DD: entry_idx=17293, exit_idx=17359, equity_len=20002
# REALIZED DD: entry_idx=17427, exit_idx=17481, equity_len=20002
# REALIZED DD: entry_idx=17559, exit_idx=17567, equity_len=20002
# REALIZED DD: entry_idx=17708, exit_idx=17743, equity_len=20002
# REALIZED DD: entry_idx=17770, exit_idx=17780, equity_len=20002
# REALIZED DD: entry_idx=17804, exit_idx=17860, equity_len=20002
# REALIZED DD: entry_idx=17935, exit_idx=17989, equity_len=20002
# REALIZED DD: entry_idx=18169, exit_idx=18229, equity_len=20002
# REALIZED DD: entry_idx=18257, exit_idx=18319, equity_len=20002
# REALIZED DD: entry_idx=18434, exit_idx=18463, equity_len=20002
# REALIZED DD: entry_idx=18474, exit_idx=18534, equity_len=20002
# REALIZED DD: entry_idx=18551, exit_idx=18560, equity_len=20002
# REALIZED DD: entry_idx=18598, exit_idx=18671, equity_len=20002
# REALIZED DD: entry_idx=18697, exit_idx=18795, equity_len=20002
# REALIZED DD: entry_idx=18904, exit_idx=18955, equity_len=20002
# REALIZED DD: entry_idx=19110, exit_idx=19257, equity_len=20002
# REALIZED DD: entry_idx=19296, exit_idx=19368, equity_len=20002
# REALIZED DD: entry_idx=19374, exit_idx=19545, equity_len=20002
# REALIZED DD: entry_idx=19547, exit_idx=19612, equity_len=20002
# REALIZED DD: entry_idx=19622, exit_idx=19696, equity_len=20002
# REALIZED DD: entry_idx=19762, exit_idx=19899, equity_len=20002
# REALIZED DD: entry_idx=19924, exit_idx=19944, equity_len=20002
# REALIZED DD: entry_idx=19979, exit_idx=19999, equity_len=20002

# %% [markdown]
# # 5. Compare Results

# %%
def print_metrics(name, results):
    print(f"--- {name} ---")
    print(f"Sharpe Ratio: {results['sharpe']:.2f}")
    print(f"Total Return: {results['total_return']*100:.2f}%")
    print(f"Annualized Return: {results['annualized_return']*100:.2f}%")
    print(f"Max Drawdown: {results['max_drawdown']*100:.2f}%")
    print(f"Number of Trades: {results['n_trades']}")
    print(f"Win Rate: {results['win_rate']*100:.2f}%")
    print()

print_metrics("Buy & Hold", bh_results)
print_metrics("SMA Crossover", sma_results)
# Out:
# --- Buy & Hold ---
# Sharpe Ratio: 1.57
# Total Return: 686.91%
# Annualized Return: 146.83%
# Max Drawdown: 32.28%
# Number of Trades: 1
# Win Rate: 100.00%
#
# --- SMA Crossover ---
# Sharpe Ratio: 0.49
# Total Return: -1.45%
# Annualized Return: -0.64%
# Max Drawdown: 50.77%
# Number of Trades: 136
# Win Rate: 33.82%

# %%
import matplotlib.dates as mdates

def plot_strategy_results(df, results, name="Strategy"):
    df = df.loc[:, ~df.columns.duplicated()]    # remove duplicate column names
    # Align index for plotting
    times = pd.to_datetime(df['time'])
    equity = results['equity_curve'].reset_index(drop=True)
    rolling_sharpe = results['rolling_sharpe'].reset_index(drop=True)
    unrealized_dd = results['unrealized_drawdown'].reset_index(drop=True)
    realized_dd = results['realized_drawdown'].reset_index(drop=True)

    fig, axs = plt.subplots(5, 1, figsize=(14, 18), sharex=True, gridspec_kw={'height_ratios': [2, 1, 2, 1, 1]})

    # 1. Price and Volume
    axs[0].plot(times, df['close'], label='BTC Price', color='blue')
    ax2 = axs[0].twinx()
    ax2.fill_between(times, df['volume'], color='gray', alpha=0.2, label='Volume')
    axs[0].set_ylabel('BTC Price')
    ax2.set_ylabel('Volume')
    axs[0].set_title(f"{name} - BTC Price and Volume")
    axs[0].legend(loc='upper left')
    ax2.legend(loc='upper right')

    # 2. Equity Curve
    axs[1].plot(times, equity[:len(times)], label='Equity Curve', color='green')
    axs[1].set_ylabel('Equity ($)')
    axs[1].set_title(f"{name} - Equity Curve")
    axs[1].legend()
    axs[1].grid(True)

    # 3. Drawdown
    axs[2].plot(times, unrealized_dd[:len(times)], label='Unrealized Drawdown', color='red')
    axs[2].plot(times, realized_dd[:len(times)], label='Realized Drawdown', color='orange', linestyle='--', marker='o', markersize=3)
    axs[2].set_ylabel('Drawdown')
    axs[2].set_title(f"{name} - Drawdown")
    axs[2].legend()
    axs[2].grid(True)

    # 4. Rolling Sharpe
    axs[3].plot(times, rolling_sharpe[:len(times)], label='Rolling Sharpe (30d)', color='purple')
    axs[3].set_ylabel('Sharpe')
    axs[3].set_title(f"{name} - Rolling Sharpe Ratio")
    axs[3].legend()
    axs[3].grid(True)

    # 5. Trades (Buy/Sell markers)
    axs[4].plot(times, df['close'], color='blue', alpha=0.5)
    # Only keep indices that are within the bounds of df/times
    buys = [idx for idx in [t['entry_idx'] for t in results['trades']] if idx < len(df)]
    sells = [idx for idx in [t['exit_idx'] for t in results['trades']] if idx < len(df)]

    axs[4].scatter(times.iloc[buys], df['close'].iloc[buys], marker='^', color='green', label='Buy', zorder=5)
    axs[4].scatter(times.iloc[sells], df['close'].iloc[sells], marker='v', color='red', label='Sell', zorder=5)
    axs[4].set_ylabel('BTC Price')
    axs[4].set_title(f"{name} - Buy/Sell Points")
    axs[4].legend()
    axs[4].grid(True)

    # X-axis formatting
    axs[-1].xaxis.set_major_locator(mdates.AutoDateLocator())
    axs[-1].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

    plt.tight_layout()
    plt.show()

plot_strategy_results(
    bt_df.rename(columns={"volumeto": "volume"}),   # plotting needs 'volume'
    sma_vec_results,
    name="SMA Vectorised",
)




# Example usage:
# plot_strategy_results(bt_df, bh_results, name="Buy & Hold")
# plot_strategy_results(bt_df, sma_results, name="SMA Crossover")
# Out:
# Loop Sharpe : 0.4932762380736324
# Vector Sharpe: 1.3153521317882515

# %%
print("Loop Sharpe :", sma_results["sharpe"])
print("Vector Sharpe:", sma_vec_results["sharpe"])
# Out:
# Loop Sharpe : 0.4932762380736324
# Vector Sharpe: 1.3153521317882515
